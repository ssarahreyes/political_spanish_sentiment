# %%
import pandas as pd

# %%
db = pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv')

# %%
db
# Out:
#                   user.name                 created_at                   id  \
# 0           Partido Popular  2021-05-04 22:06:48+00:00  1389703079344345093
# 1           Partido Popular  2021-05-04 21:07:53+00:00  1389688253469663234
# 2           Partido Popular  2021-05-04 20:40:12+00:00  1389681286353244163
# 3           Partido Popular  2021-05-04 20:39:36+00:00  1389681134183845895
# 4           Partido Popular  2021-05-04 20:31:38+00:00  1389679129755332622
# ...                     ...                        ...                  ...
# 257819                Susan  2021-05-10 22:02:15+00:00  1391876261669113856
# 257820       Laura Catalina  2021-05-10 22:02:11+00:00  1391876247819595779
# 257821               cris02  2021-05-10 22:02:10+00:00  1391876241142263813
# 257822     Miguel Castrejon  2021-05-10 22:02:09+00:00  1391876239275839489
# 257823  La Voz | Ciudadanos  2021-05-10 22:02:01+00:00  1391876203410337795
#
# ...

# %%
# Out:
# '2021-05-14 23:57:44+00:00'

# %%
db.shape
# Out:
# (306657, 20)

# %%
db_fix = db[db['sentimiento'].isnull()]

# %%
db_fix
# Out:
#         Unnamed: 0                                     index1  \
# 202570           0                                        beg
# 202571           1  Mujeres en Igualdad-Distrito de Salamanca
# 202572           2                                 Empla10001
# 202573           3                                     Quique
# 202574           4                                         JP
# ...            ...                                        ...
# 306652         195                                Edmundo Bal
# 306653         196                                Edmundo Bal
# 306654         197                                Edmundo Bal
# 306655         198                                Edmundo Bal
# 306656         199                                Edmundo Bal
#
#                            index2            user.name  \
# 202570  2021-04-30 23:58:21+00:00  1388281600165695492
# 202571  2021-04-30 23:57:51+00:00  1388281475024437250
# ...

# %%
db_fix.drop(columns=['sentimiento', 'scores'], inplace=True)
# Out:
# /Users/sarahr/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fix_columns = ['Unnamed: 0', 'user.name', 'created_at', 'id', 'full_text', 
               'display_text_range', 'source', 'retweet_count', 'favorite_count', 
               'user.followers_count', 'user.friends_count', 'user.statuses_count', 
               'partido', 'tipo de post', 'campaña', 'hashtags', 'sentimiento', 'scores']

db_fix.columns = fix_columns

# %%
db_fix.columns = fix_columns

# %%
db_fix
# Out:
#         Unnamed: 0                                  user.name  \
# 202570           0                                        beg
# 202571           1  Mujeres en Igualdad-Distrito de Salamanca
# 202572           2                                 Empla10001
# 202573           3                                     Quique
# 202574           4                                         JP
# ...            ...                                        ...
# 306652         195                                Edmundo Bal
# 306653         196                                Edmundo Bal
# 306654         197                                Edmundo Bal
# 306655         198                                Edmundo Bal
# 306656         199                                Edmundo Bal
#
#                        created_at                   id  \
# 202570  2021-04-30 23:58:21+00:00  1388281600165695492
# 202571  2021-04-30 23:57:51+00:00  1388281475024437250
# ...

# %%
db.drop(columns=['index1', 'index2'], inplace=True)

# %%
db_big = db.drop(db.index[104087:306657])

# %%
big_columns = db_big.columns.tolist()

# %%
new_big_columns = ['Unnamed: 0',
 'user.name',
 'created_at',
 'id',
 'full_text',
 'display_text_range',
 'source',
 'retweet_count',
 'favorite_count',
 'user.followers_count',
 'user.friends_count',
 'user.statuses_count',
 'partido',
 'tipo de post',
 'hashtags',
'campaña',
 'sentimiento',
 'scores']

# %%
db_big_correct = db_big[new_big_columns]

# %%
db_big_correct.columns = big_columns

# %%
db_big_correct
# Out:
#         Unnamed: 0                user.name                 created_at  \
# 0                0            jesu lopez lo  2021-04-28 13:35:20+00:00
# 1                1            Miguel Benito  2021-04-28 13:35:14+00:00
# 2                2   Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3                3                Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4                4                   Mentxu  2021-04-28 13:34:55+00:00
# ...            ...                      ...                        ...
# 104082      104082                   Juanma  2021-04-27 21:33:08+00:00
# 104083      104083          Franklin Chavez  2021-04-27 21:33:06+00:00
# 104084      104084  Vista, suerte y al toro  2021-04-27 21:33:06+00:00
# 104085      104085               PabloTuruS  2021-04-27 21:33:04+00:00
# 104086      104086              Onda Madrid  2021-04-27 21:33:04+00:00
#
#                          id  \
# 0       1387400036624080899
# 1       1387400014406852611
# ...

# %%
db_fix
# Out:
#         Unnamed: 0                                  user.name  \
# 202570           0                                        beg
# 202571           1  Mujeres en Igualdad-Distrito de Salamanca
# 202572           2                                 Empla10001
# 202573           3                                     Quique
# 202574           4                                         JP
# ...            ...                                        ...
# 306652         195                                Edmundo Bal
# 306653         196                                Edmundo Bal
# 306654         197                                Edmundo Bal
# 306655         198                                Edmundo Bal
# 306656         199                                Edmundo Bal
#
#                        created_at                   id  \
# 202570  2021-04-30 23:58:21+00:00  1388281600165695492
# 202571  2021-04-30 23:57:51+00:00  1388281475024437250
# ...

# %%
frames = [db_big_correct, db_fix]

# %%
db_final = pd.concat(frames)

# %%
db_final
# Out:
#         Unnamed: 0               user.name                 created_at  \
# 0                0           jesu lopez lo  2021-04-28 13:35:20+00:00
# 1                1           Miguel Benito  2021-04-28 13:35:14+00:00
# 2                2  Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3                3               Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4                4                  Mentxu  2021-04-28 13:34:55+00:00
# ...            ...                     ...                        ...
# 306652         195             Edmundo Bal  2021-03-09 14:00:17+00:00
# 306653         196             Edmundo Bal  2021-03-09 09:13:14+00:00
# 306654         197             Edmundo Bal  2021-03-08 19:06:08+00:00
# 306655         198             Edmundo Bal  2021-03-08 11:37:53+00:00
# 306656         199             Edmundo Bal  2021-03-08 10:05:14+00:00
#
#                          id  \
# 0       1387400036624080899
# 1       1387400014406852611
# 2       1387399988846776322
# ...

# %%
id_uniques = db_final['id'].unique().tolist()

# %%
db_no_duplicates = db_final[db_final['id'].isin(id_uniques)]

# %%
db_no_duplicates
# Out:
#         Unnamed: 0               user.name                 created_at  \
# 0                0           jesu lopez lo  2021-04-28 13:35:20+00:00
# 1                1           Miguel Benito  2021-04-28 13:35:14+00:00
# 2                2  Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3                3               Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4                4                  Mentxu  2021-04-28 13:34:55+00:00
# ...            ...                     ...                        ...
# 306652         195             Edmundo Bal  2021-03-09 14:00:17+00:00
# 306653         196             Edmundo Bal  2021-03-09 09:13:14+00:00
# 306654         197             Edmundo Bal  2021-03-08 19:06:08+00:00
# 306655         198             Edmundo Bal  2021-03-08 11:37:53+00:00
# 306656         199             Edmundo Bal  2021-03-08 10:05:14+00:00
#
#                          id  \
# 0       1387400036624080899
# 1       1387400014406852611
# 2       1387399988846776322
# ...

# %%
def madrid_campaña(df, column):
    
    column_list = list(column)
    
    campaña = []
    
    for t in column_list:
        if 'Madrid' in t:
            campaña.append('madrid')
        else:
            campaña.append('general')
            
    df['campaña'] = campaña
    
    return df

# pasarle esta función a todo el datafrae que tenga mañana y añadirla en las funciones del main script.

# %%
madrid_campaña(db_no_duplicates, db_no_duplicates['full_text'])
# Out:
#         Unnamed: 0               user.name                 created_at  \
# 0                0           jesu lopez lo  2021-04-28 13:35:20+00:00
# 1                1           Miguel Benito  2021-04-28 13:35:14+00:00
# 2                2  Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3                3               Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4                4                  Mentxu  2021-04-28 13:34:55+00:00
# ...            ...                     ...                        ...
# 306652         195             Edmundo Bal  2021-03-09 14:00:17+00:00
# 306653         196             Edmundo Bal  2021-03-09 09:13:14+00:00
# 306654         197             Edmundo Bal  2021-03-08 19:06:08+00:00
# 306655         198             Edmundo Bal  2021-03-08 11:37:53+00:00
# 306656         199             Edmundo Bal  2021-03-08 10:05:14+00:00
#
#                          id  \
# 0       1387400036624080899
# 1       1387400014406852611
# 2       1387399988846776322
# ...

# %%
db_no_duplicates[db_no_duplicates['partido'] == 'CUIDADANOS']
# Out:
#         Unnamed: 0                                          user.name  \
# 247570           0                                        Jean Pierre
# 247571           1                                David Sierra Zuleta
# 247572           2                                              c. mu
# 247573           3                               waldistrudis Hurtado
# 247574           4  eso.."me niego radicalmente a la polarización"...
# ...            ...                                                ...
# 298765        1995                                        SARA MORA..
# 298766        1996                                      Satanislavsky
# 298767        1997                             Juan Alejandro Sánchez
# 298768        1998                                       Miki / 🇭🇰🇦🇩🐍
# 298769        1999                                         Mrs. Bᥲss🌼
#
#                        created_at                   id  \
# 247570  2021-04-30 23:59:58+00:00  1388282007302590467
# ...

# %%
db_no_duplicates.loc[db_no_duplicates['partido'] == 'CUIDADANOS', 'partido'] = 'CIUDADANOS'

# %%
db_no_duplicates[db_no_duplicates['partido'] == 'CUIDADANOS']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, user.name, created_at, id, full_text, display_text_range, source, retweet_count, favorite_count, user.followers_count, user.friends_count, user.statuses_count, partido, tipo de post, campaña, hashtags, sentimiento, scores]
# Index: []

# %%
# exporting the final data base and change the name
db_no_duplicates.to_csv('../data/data_bases/political_spanish_sentiment_final_ddbb_correct.csv', index=False)

# %%
# updating the final data base with tweets and mentions of yesterday. (sat afternoon)

# %%
# automating main.py and publish a tweet with the last results.  (sunday)

#@sentimientopolitico_esp: (Hoy, 4 de mayo de 2021, el partido político español más positivo en Twitter es XXX y el más negativo XXX. Revisa los resultados en: TABLEAU)

# %%
# change for yesterday el script para ejecutarlo todos los días.

# %%
db_notableau = pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv')

# %%
db_notableau
# Out:
#           0                Adrián  2021-05-04 23:59:57+00:00  \
# 0         1               Gabriel  2021-05-04 23:59:54+00:00
# 1         2            Jesús Caro  2021-05-04 23:59:53+00:00
# 2         3          Rikitikishow  2021-05-04 23:59:47+00:00
# 3         4               toc-toc  2021-05-04 23:59:47+00:00
# 4         5            J.Alanzabe  2021-05-04 23:59:46+00:00
# ...     ...                   ...                        ...
# 11994  1995       𝖍𝖚𝖗𝖆𝖈𝖆𝖓 𝖕𝖆𝖙𝖗𝖎𝖓𝖆  2021-05-04 22:17:46+00:00
# 11995  1996         Pelayo García  2021-05-04 22:17:45+00:00
# 11996  1997      MadridTabernario  2021-05-04 22:17:43+00:00
# 11997  1998  Guillermo García ⚽🏀🏐  2021-05-04 22:17:41+00:00
# 11998  1999               Prúsica  2021-05-04 22:17:41+00:00
#
#        1389731554302246918  \
# 0      1389731543476805635
# 1      1389731538896568321
# 2      1389731515098148868
# 3      1389731511902117888
# 4      1389731509729386500
# ...                    ...
# 11994  1389705838974152705
# ...

# %%
db_tableau = pd.read_csv('../data/data_bases/political_spanish_sentiment_final_ddbb.csv')

# %%
db_tableau
# Out:
#         Unnamed: 0               user.name                 created_at  \
# 0                0           jesu lopez lo  2021-04-28 13:35:20+00:00
# 1                1           Miguel Benito  2021-04-28 13:35:14+00:00
# 2                2  Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3                3               Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4                4                  Mentxu  2021-04-28 13:34:55+00:00
# ...            ...                     ...                        ...
# 208169         195             Edmundo Bal  2021-03-09 14:00:17+00:00
# 208170         196             Edmundo Bal  2021-03-09 09:13:14+00:00
# 208171         197             Edmundo Bal  2021-03-08 19:06:08+00:00
# 208172         198             Edmundo Bal  2021-03-08 11:37:53+00:00
# 208173         199             Edmundo Bal  2021-03-08 10:05:14+00:00
#
#                          id  \
# 0       1387400036624080899
# 1       1387400014406852611
# 2       1387399988846776322
# ...

# %%
fix_columns = ['Unnamed: 0', 'user.name', 'created_at', 'id', 'full_text', 
               'display_text_range', 'source', 'retweet_count', 'favorite_count', 
               'user.followers_count', 'user.friends_count', 'user.statuses_count', 
               'partido', 'tipo de post', 'campaña', 'hashtags', 'sentimiento', 'scores']

db_notableau.columns = fix_columns

# %%
db_notableau
# Out:
#        Unnamed: 0             user.name                 created_at  \
# 0               1               Gabriel  2021-05-04 23:59:54+00:00
# 1               2            Jesús Caro  2021-05-04 23:59:53+00:00
# 2               3          Rikitikishow  2021-05-04 23:59:47+00:00
# 3               4               toc-toc  2021-05-04 23:59:47+00:00
# 4               5            J.Alanzabe  2021-05-04 23:59:46+00:00
# ...           ...                   ...                        ...
# 11994        1995       𝖍𝖚𝖗𝖆𝖈𝖆𝖓 𝖕𝖆𝖙𝖗𝖎𝖓𝖆  2021-05-04 22:17:46+00:00
# 11995        1996         Pelayo García  2021-05-04 22:17:45+00:00
# 11996        1997      MadridTabernario  2021-05-04 22:17:43+00:00
# 11997        1998  Guillermo García ⚽🏀🏐  2021-05-04 22:17:41+00:00
# 11998        1999               Prúsica  2021-05-04 22:17:41+00:00
#
#                         id                                          full_text  \
# 0      1389731543476805635  Deja la vicepresidencia, gana Ayuso y se retir...
# ...

# %%
dbs = [db_tableau, db_notableau]

# %%
db_uptadted = pd.concat(dbs)

# %%
db_uptadted.to_csv('../data/data_bases/political_spanish_sentiment_final_ddbb.csv')

# %%
db_uptadted
# Out:
#        Unnamed: 0               user.name                 created_at  \
# 0               0           jesu lopez lo  2021-04-28 13:35:20+00:00
# 1               1           Miguel Benito  2021-04-28 13:35:14+00:00
# 2               2  Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3               3               Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4               4                  Mentxu  2021-04-28 13:34:55+00:00
# ...           ...                     ...                        ...
# 11994        1995         𝖍𝖚𝖗𝖆𝖈𝖆𝖓 𝖕𝖆𝖙𝖗𝖎𝖓𝖆  2021-05-04 22:17:46+00:00
# 11995        1996           Pelayo García  2021-05-04 22:17:45+00:00
# 11996        1997        MadridTabernario  2021-05-04 22:17:43+00:00
# 11997        1998    Guillermo García ⚽🏀🏐  2021-05-04 22:17:41+00:00
# 11998        1999                 Prúsica  2021-05-04 22:17:41+00:00
#
#                         id                                          full_text  \
# ...

# %%
db_uptadted['id'].max()
# Out:
# 1389731565308104707

# %%
db_uptadted[db_uptadted['id'] == db_uptadted['id'].max()]
# Out:
#       Unnamed: 0 user.name                 created_at                   id  \
# 3999           0    Andrés  2021-05-04 23:59:59+00:00  1389731565308104707
#
#                                               full_text display_text_range  \
# 3999  @emefeuve Pablo Iglesias si lo ha hecho bien c...           [10, 72]
#
#                    source  retweet_count  favorite_count  \
# 3999  Twitter for Android              0               1
#
#       user.followers_count  user.friends_count  user.statuses_count  partido  \
# 3999                     2                  36                    9  PODEMOS
#
#      tipo de post  campaña hashtags  sentimiento    scores
# 3999      mención  general       []          3.0  0.336475

# %%
db_uptadted.groupby('partido').agg({'id': 'max'})
# Out:
#                                   id
# partido
# CIUDADANOS       1389731550204502025
# Más Madrid       1389731564104437763
# PODEMOS          1389731565308104707
# PSOE             1389731563932459018
# Partido Popular  1389731543476805635
# VOX              1389731558060351489

# %%
db_uptadted.groupby('partido').agg({'sentimiento': 'mean'})
# Out:
#                  sentimiento
# partido
# CIUDADANOS          2.190895
# Más Madrid          1.997717
# PODEMOS             2.005598
# PSOE                1.711713
# Partido Popular     1.788296
# VOX                 1.853852

# %%
db_uptadted.loc[db_uptadted['user.name'] == 'Isabel Díaz Ayuso', 'partido'] = 'Partido Popular'

# %%
db_uptadted.loc[db_uptadted['user.name'] == 'Más Madrid', 'partido'] = 'Más Madrid'

# %%
db_uptadted[db_uptadted['user.name'] == 'Partido Popular'].groupby('partido').count()
# Out:
#                  Unnamed: 0  user.name  created_at    id  full_text  \
# partido
# CIUDADANOS                4          4           4     4          4
# PODEMOS                   1          1           1     1          1
# PSOE                      5          5           5     5          5
# Partido Popular        1215       1215        1215  1215       1215
#
#                  display_text_range  source  retweet_count  favorite_count  \
# partido
# CIUDADANOS                        4       4              4               4
# PODEMOS                           1       1              1               1
# PSOE                              5       5              5               5
# Partido Popular                1215    1215           1215            1215
#
#                  user.followers_count  user.friends_count  \
# partido
# CIUDADANOS                          4                   4
# PODEMOS                             1                   1
# ...

# %%
db_uptadted[(db_uptadted['user.name'] == 'Partido Popular') & (db_uptadted['partido'] == 'PODEMOS')]['full_text'].tolist()
# Out:
# ['🔵 @IdiazAyuso: “En este #DíaDelTrabajador, estoy viendo a Errejón preocupada porque, si dice que hay que trabajar 4 días y hoy es sábado, ¿qué habrá hecho desde el jueves? ¿E Iglesias? Huir también, porque en la Asamblea hay pleno todos los jueves”.\n\n#YoConAyuso #VotaLIBERTAD https://t.co/1xVSkkTohS']

# %%
db_uptadted.to_csv('../data/data_bases/political_spanish_sentiment_ddbb_2.csv')

# %%
db_uptadted.groupby('partido').agg({'retweet_count':'sum', 'favorite_count':'sum'})
# Out:
#                  retweet_count  favorite_count
# partido
# CIUDADANOS             1404137         3662820
# Más Madrid              771276         2246986
# PODEMOS                3201930         9123251
# PSOE                    950506         2998828
# Partido Popular        3639283        12256909
# VOX                    3272556         8489493

# %%
db_uptadted.shape
# Out:
# (220173, 18)

# %%
db_tweets = pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv', index_col=0)
# Out:
# /Users/sarahr/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1,4,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
db_tweets
# Out:
#     Unnamed: 0.1                  user.name                 created_at  \
# 0              0              jesu lopez lo  2021-04-28 13:35:20+00:00
# 1              1              Miguel Benito  2021-04-28 13:35:14+00:00
# 2              2     Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00
# 3              3                  Ritxi ·🔻·  2021-04-28 13:35:03+00:00
# 4              4                     Mentxu  2021-04-28 13:34:55+00:00
# ..           ...                        ...                        ...
# 195  Edmundo Bal  2021-03-09 18:38:00+00:00        1369356813586546688
# 196  Edmundo Bal  2021-03-09 14:00:17+00:00        1369286925580959745
# 197  Edmundo Bal  2021-03-09 09:13:14+00:00        1369214684965003269
# 198  Edmundo Bal  2021-03-08 19:06:08+00:00        1369001506058469376
# 199  Edmundo Bal  2021-03-08 11:37:53+00:00        1368888699463819265
#
#                                                     id  \
# 0                                  1387400036624080899
# ...

# %%
db_tweets[db_tweets['partido'] == 'publicación']
# Out:
#         Unnamed: 0     Unnamed: 0.1                  user.name  \
# 220173           0  Partido Popular  2021-05-04 22:06:48+00:00
# 220174           1  Partido Popular  2021-05-04 21:07:53+00:00
# 220175           2  Partido Popular  2021-05-04 20:40:12+00:00
# 220176           3  Partido Popular  2021-05-04 20:39:36+00:00
# 220177           4  Partido Popular  2021-05-04 20:31:38+00:00
# ...            ...              ...                        ...
# 223987         195      Edmundo Bal  2021-03-09 18:38:00+00:00
# 223988         196      Edmundo Bal  2021-03-09 14:00:17+00:00
# 223989         197      Edmundo Bal  2021-03-09 09:13:14+00:00
# 223990         198      Edmundo Bal  2021-03-08 19:06:08+00:00
# 223991         199      Edmundo Bal  2021-03-08 11:37:53+00:00
#
#                  created_at  \
# 220173  1389703079344345093
# 220174  1389688253469663234
# 220175  1389681286353244163
# 220176  1389681134183845895
# 220177  1389679129755332622
# ...                     ...
# ...

# %%
# fixing the index

# %%
db_tweets.shape
# Out:
# (223992, 18)

# %%
db_nuevo.drop(columns=['scores'], inplace=True)
# Out:
# /Users/sarahr/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
db_antiguo = db_tweets[db_tweets['scores'].notna()]

# %%
db_nuevo = db_tweets[db_tweets['scores'].isna()]

# %%
new_nuevo_columns = ['user.name', 
                     'created_at', 
                     'id',
                     'full_text',
                     'display_text_range',
                     'source',
                     'retweet_count',
                     'favorite_count',
                     'user.followers_count',
                     'user.friends_count',
                     'user.statuses_count',
                     'partido',
                     'tipo de post',
                     'campaña',
                     'hashtags',
                     'sentimiento',
                     'scores']

# %%
db_nuevo.columns = new_nuevo_columns

# %%
db_nuevo
# Out:
#            user.name                 created_at                   id  \
# 0    Partido Popular  2021-05-04 22:06:48+00:00  1389703079344345093
# 1    Partido Popular  2021-05-04 21:07:53+00:00  1389688253469663234
# 2    Partido Popular  2021-05-04 20:40:12+00:00  1389681286353244163
# 3    Partido Popular  2021-05-04 20:39:36+00:00  1389681134183845895
# 4    Partido Popular  2021-05-04 20:31:38+00:00  1389679129755332622
# ..               ...                        ...                  ...
# 195      Edmundo Bal  2021-03-09 18:38:00+00:00  1369356813586546688
# 196      Edmundo Bal  2021-03-09 14:00:17+00:00  1369286925580959745
# 197      Edmundo Bal  2021-03-09 09:13:14+00:00  1369214684965003269
# 198      Edmundo Bal  2021-03-08 19:06:08+00:00  1369001506058469376
# 199      Edmundo Bal  2021-03-08 11:37:53+00:00  1368888699463819265
#
#                                              full_text display_text_range  \
# ...

# %%
db_antiguo.drop(columns='Unnamed: 0.1', inplace=True)
# Out:
# /Users/sarahr/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
db_antiguo
# Out:
#                     user.name                 created_at                   id  \
# 0               jesu lopez lo  2021-04-28 13:35:20+00:00  1387400036624080899
# 1               Miguel Benito  2021-04-28 13:35:14+00:00  1387400014406852611
# 2      Bernardo Diaz Martínez  2021-04-28 13:35:08+00:00  1387399988846776322
# 3                   Ritxi ·🔻·  2021-04-28 13:35:03+00:00  1387399968097509377
# 4                      Mentxu  2021-04-28 13:34:55+00:00  1387399934052347915
# ...                       ...                        ...                  ...
# 11994         𝖍𝖚𝖗𝖆𝖈𝖆𝖓 𝖕𝖆𝖙𝖗𝖎𝖓𝖆  2021-05-04 22:17:46+00:00  1389705838974152705
# 11995           Pelayo García  2021-05-04 22:17:45+00:00  1389705835232825344
# 11996        MadridTabernario  2021-05-04 22:17:43+00:00  1389705827855052800
# 11997    Guillermo García ⚽🏀🏐  2021-05-04 22:17:41+00:00  1389705821160804352
# 11998                 Prúsica  2021-05-04 22:17:41+00:00  1389705820015763457
#
# ...

# %%
frames_last = [db_nuevo, db_antiguo]

# %%
db_final_noindex = pd.concat(frames_last)

# %%
db_final_noindex.to_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv', index=False)

# %%
db_final_noindex[db_final_noindex['partido'] == 'publicación']
# Out:
# Empty DataFrame
# Columns: [user.name, created_at, id, full_text, display_text_range, source, retweet_count, favorite_count, user.followers_count, user.friends_count, user.statuses_count, partido, tipo de post, campaña, hashtags, sentimiento, scores]
# Index: []

# %%
db_final_noindex[db_final_noindex['tipo de post'] == 'general']
# Out:
# Empty DataFrame
# Columns: [user.name, created_at, id, full_text, display_text_range, source, retweet_count, favorite_count, user.followers_count, user.friends_count, user.statuses_count, partido, tipo de post, campaña, hashtags, sentimiento, scores]
# Index: []

# %%
db_final_noindex['created_at'].max()
# Out:
# '2021-05-04 23:59:59+00:00'

# %%
if 'user.name' in db_nuevo:
    print('yes')
# Out:
# yes

# %%
if 'user.name' in df_tweets_filtered:
    columns_selected = ['created_at', 'id', 'full_text', 'display_text_range',
                        'source', 'retweet_count', 'favorite_count', 'user.followers_count',
                        'user.friends_count', 'user.statuses_count']

    df_tweets_filtered = db_nuevo[columns_selected]
    
else:
    pass

# %%
df_tweets_filtered
# Out:
#                     created_at                   id  \
# 0    2021-05-04 22:06:48+00:00  1389703079344345093
# 1    2021-05-04 21:07:53+00:00  1389688253469663234
# 2    2021-05-04 20:40:12+00:00  1389681286353244163
# 3    2021-05-04 20:39:36+00:00  1389681134183845895
# 4    2021-05-04 20:31:38+00:00  1389679129755332622
# ..                         ...                  ...
# 195  2021-03-09 18:38:00+00:00  1369356813586546688
# 196  2021-03-09 14:00:17+00:00  1369286925580959745
# 197  2021-03-09 09:13:14+00:00  1369214684965003269
# 198  2021-03-08 19:06:08+00:00  1369001506058469376
# 199  2021-03-08 11:37:53+00:00  1368888699463819265
#
#                                              full_text display_text_range  \
# 0    La LIBERTAD ha triunfado.\n\n🔵@IdiazAyuso http...            [0, 39]
# 1    ¡Viva el Partido Popular!\n¡Viva Isabel Díaz A...            [0, 89]
# 2    🔵 @IdiazAyuso: “Los bienes más preciados que t...           [0, 136]
# ...

# %%
pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv')
# Out:
#               user.name                 created_at                   id  \
# 0       Partido Popular  2021-05-04 22:06:48+00:00  1389703079344345093
# 1       Partido Popular  2021-05-04 21:07:53+00:00  1389688253469663234
# 2       Partido Popular  2021-05-04 20:40:12+00:00  1389681286353244163
# 3       Partido Popular  2021-05-04 20:39:36+00:00  1389681134183845895
# 4       Partido Popular  2021-05-04 20:31:38+00:00  1389679129755332622
# ...                 ...                        ...                  ...
# 251819      Edmundo Bal  2021-03-11 18:01:13+00:00  1370072333025697792
# 251820      Edmundo Bal  2021-03-11 10:07:11+00:00  1369953038274793475
# 251821      Edmundo Bal  2021-03-09 18:38:00+00:00  1369356813586546688
# 251822      Edmundo Bal  2021-03-09 14:00:17+00:00  1369286925580959745
# 251823      Edmundo Bal  2021-03-09 09:13:14+00:00  1369214684965003269
#
#                                                 full_text display_text_range  \
# ...

# %%
df = pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv')

# %%
df.groupby(['created_at', 'tipo de post']).mean().round(2)
# Out:
#                                                   id  retweet_count  \
# created_at                tipo de post
# 2019-10-27 14:12:32+00:00 publicación   1.188458e+18          134.0
# 2019-10-28 15:40:12+00:00 publicación   1.188843e+18          116.0
# 2019-10-28 17:28:56+00:00 publicación   1.188870e+18           34.0
# 2019-10-28 19:10:49+00:00 publicación   1.188896e+18           84.0
# 2019-10-29 06:02:19+00:00 publicación   1.189060e+18          134.0
# ...                                              ...            ...
# 2021-05-06 23:59:47+00:00 mención       1.390456e+18            0.0
# 2021-05-06 23:59:49+00:00 mención       1.390456e+18            0.0
# 2021-05-06 23:59:52+00:00 mención       1.390456e+18            0.0
# 2021-05-06 23:59:54+00:00 mención       1.390456e+18            0.5
# 2021-05-06 23:59:59+00:00 mención       1.390456e+18            0.0
#
#                                         favorite_count  user.followers_count  \
# ...

# %%
df
# Out:
#               user.name                 created_at                   id  \
# 0       Partido Popular  2021-05-04 22:06:48+00:00  1389703079344345093
# 1       Partido Popular  2021-05-04 21:07:53+00:00  1389688253469663234
# 2       Partido Popular  2021-05-04 20:40:12+00:00  1389681286353244163
# 3       Partido Popular  2021-05-04 20:39:36+00:00  1389681134183845895
# 4       Partido Popular  2021-05-04 20:31:38+00:00  1389679129755332622
# ...                 ...                        ...                  ...
# 251819      Edmundo Bal  2021-03-11 18:01:13+00:00  1370072333025697792
# 251820      Edmundo Bal  2021-03-11 10:07:11+00:00  1369953038274793475
# 251821      Edmundo Bal  2021-03-09 18:38:00+00:00  1369356813586546688
# 251822      Edmundo Bal  2021-03-09 14:00:17+00:00  1369286925580959745
# 251823      Edmundo Bal  2021-03-09 09:13:14+00:00  1369214684965003269
#
#                                                 full_text display_text_range  \
# ...

# %%
pd.to_datetime(df['created_at'])
# Out:
# 0        2021-05-04 22:06:48+00:00
# 1        2021-05-04 21:07:53+00:00
# 2        2021-05-04 20:40:12+00:00
# 3        2021-05-04 20:39:36+00:00
# 4        2021-05-04 20:31:38+00:00
#                     ...
# 251819   2021-03-11 18:01:13+00:00
# 251820   2021-03-11 10:07:11+00:00
# 251821   2021-03-09 18:38:00+00:00
# 251822   2021-03-09 14:00:17+00:00
# 251823   2021-03-09 09:13:14+00:00
# Name: created_at, Length: 251824, dtype: datetime64[ns, UTC]

# %%
df[df['sentimiento'].isnull()]
# Out:
# Empty DataFrame
# Columns: [user.name, created_at, id, full_text, display_text_range, source, retweet_count, favorite_count, user.followers_count, user.friends_count, user.statuses_count, partido, tipo de post, campaña, hashtags, sentimiento, scores]
# Index: []

# %%
df['sentimiento'].astype(float)
# Out:
# 0         1.0
# 1         5.0
# 2         5.0
# 3         1.0
# 4         2.0
#          ...
# 251819    1.0
# 251820    5.0
# 251821    5.0
# 251822    1.0
# 251823    5.0
# Name: sentimiento, Length: 251824, dtype: float64

# %%
df.to_csv('../data/data_bases/political_spanish_sentiment_ddbb_2.csv', index=False)
