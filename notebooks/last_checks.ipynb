# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_bases/political_spanish_sentiment_ddbb.csv')

# %%
df['created_at'].max()
# Out:
# '2021-05-21 23:59:52+00:00'

# %%
df[(df['sentimiento'] == 5) & (df['tipo de post'] == 'mención')]['full_text'].tolist()
# Out:
# ['@torosleganes @IdiazAyuso @ComunidadMadrid @noelia_n @populares @ppmadrid @PPAsamblea No me lo pierdo 😏',
#  'LLeva toda la vida puesta a dedo en el PP https://t.co/4HX7bJmQk3',
#  '@megatipo Dentro de unos años la hostelería con las cocinas fantasmas, sus amigos del Partido popular que apoyan todas estas plataformas , trabajos precarios y fondos buitres.',
#  '@populares @IdiazAyuso Casado, Cifuentes los másteres😄😄😄',
#  '💙 El @ppmadrid presenta su programa deportivo para el #4M ante los clubes de #Majadahonda \n\n😊 Ayer nos visitó @ECarballedo. \nTe contamos cómo fue👇\nhttps://t.co/j6rFKJr89V',
#  '@Commonsense2182 @populares Ya te vale... 😂😂😂',
#  '@populares @anadebande @IdiazAyuso Pues es lo mejor que podría pasarle a España. Que Sánchez e Iván Redondo dejen Moncloa.',
# ...

# %%
df[df['full_text'] ==  '@populares @pablocasado_ Hostia puta!!! Pero se puede ser más imbécil? Anda chaval antes de hablar piensa lo que dices, que eres tu el que día si y día también estas tocando los cojones porque no gobiernas y nunca lo harás porque te está comiendo la merienda Ayuso, estás acabado como Pablo Iglesias 🤮🤮']
# Out:
#         user.name                 created_at                   id  \
# 3856  🦁VALDELARCO  2021-04-28 13:31:09+00:00  1387398985204252676
#
#                                               full_text display_text_range  \
# 3856  @populares @pablocasado_ Hostia puta!!! Pero s...          [25, 302]
#
#                        source  retweet_count  favorite_count  \
# 3856  ['Twitter for Android']              0               0
#
#       user.followers_count  user.friends_count  user.statuses_count  \
# 3856                    84                 143                 6093
#
#               partido tipo de post  campaña hashtags  sentimiento    scores
# 3856  Partido Popular      mención  general       []          1.0  0.430835
